# %% [markdown]
# <a href="https://colab.research.google.com/github/Furyati/InternetBanking/blob/main/tools_research.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('dupa dupa dupa')
print('Pawła kupa')
# Out:
# dupa dupa dupa
